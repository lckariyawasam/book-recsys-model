# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('../data/amz-book/train (2).csv')
test = pd.read_csv('/kaggle/input/amz-book/test (3).csv')

# %%
train.head()
# Out:
#    score        time      id  user_id
# 0    5.0  1355702400   92408    41587
# 1    5.0  1356220800   32520    24303
# 2    4.0  1330560000  112766    56189
# 3    4.0  1006128000   97297     3294
# 4    5.0  1290816000   20794    50340

# %%
# !git clone https://github.com/microsoft/recommenders.git ./recommenders_microsoft
# Out:
# Cloning into './recommenders_microsoft'...
# remote: Enumerating objects: 42928, done.
# remote: Counting objects: 100% (6452/6452), done.
# remote: Compressing objects: 100% (2181/2181), done.
# remote: Total 42928 (delta 4259), reused 5748 (delta 3877), pack-reused 36476 (from 1)
# Receiving objects: 100% (42928/42928), 218.13 MiB | 34.00 MiB/s, done.
# Resolving deltas: 100% (28904/28904), done.

# %%
# !pip install retrying
# Out:
# Requirement already satisfied: retrying in /opt/conda/lib/python3.10/site-packages (1.3.3)
# Requirement already satisfied: six>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from retrying) (1.16.0)

# %%
import sys
import os
sys.path.insert(0, './recommenders_microsoft')
sys.path.insert(0, './recommenders_microsoft/recommenders')

# %%
import sys
import os
import pandas as pd
import numpy as np
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

from recommenders.utils.timer import Timer
from recommenders.models.deeprec.models.graphrec.lightgcn import LightGCN
from recommenders.models.deeprec.DataModel.ImplicitCF import ImplicitCF
from recommenders.datasets.python_splitters import python_stratified_split
from recommenders.evaluation.python_evaluation import map, ndcg_at_k, precision_at_k, recall_at_k
from recommenders.utils.constants import SEED as DEFAULT_SEED
from recommenders.models.deeprec.deeprec_utils import prepare_hparams
from recommenders.utils.notebook_utils import store_metadata

print(f"System version: {sys.version}")
print(f"Pandas version: {pd.__version__}")
print(f"Tensorflow version: {tf.__version__}")
# Out:
# System version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Pandas version: 2.2.2
# Tensorflow version: 2.16.1

# %%
train = train.rename(columns = {'user_id':'userID', 'id':'itemID','score':'rating'})
test = test.rename(columns = {'user_id':'userID', 'id':'itemID','score':'rating'})

# %%
data = ImplicitCF(
    train=train, test=test, seed=0,
    col_user='userID',
    col_item='itemID',
    col_rating='rating'
)

# %%
yaml_file = './recommenders_microsoft/examples/07_tutorials/KDD2020-tutorial/lightgcn.yaml'


hparams = prepare_hparams(yaml_file,                          
                          learning_rate=0.01,
                          eval_epoch=1,
                          top_k=10,
                          save_model=True,
                          epochs=50,
                          save_epoch=1
                         )

# %%
model = LightGCN(hparams, data, seed=0)
# Out:
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.

# %%
with Timer() as train_time:
    model.fit()

print("Took {} seconds for training.".format(train_time.interval))
# Out:
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_1
# Epoch 1 (train)5.3s + (eval)12.5s: train loss = 0.24871 = (mf)0.24789 + (embed)0.00083, recall = 0.15972, ndcg = 0.11277, precision = 0.02390, map = 0.09032
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_2
# Epoch 2 (train)4.7s + (eval)12.4s: train loss = 0.04636 = (mf)0.04443 + (embed)0.00192, recall = 0.20818, ndcg = 0.15042, precision = 0.03048, map = 0.12296
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_3
# Epoch 3 (train)4.6s + (eval)12.5s: train loss = 0.02555 = (mf)0.02307 + (embed)0.00248, recall = 0.23630, ndcg = 0.17411, precision = 0.03424, map = 0.14434
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_4
# Epoch 4 (train)4.6s + (eval)12.3s: train loss = 0.01813 = (mf)0.01528 + (embed)0.00284, recall = 0.25495, ndcg = 0.18929, precision = 0.03688, map = 0.15790
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_5
# Epoch 5 (train)4.8s + (eval)12.4s: train loss = 0.01463 = (mf)0.01152 + (embed)0.00311, recall = 0.26885, ndcg = 0.20254, precision = 0.03879, map = 0.17039
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_6
# Epoch 6 (train)4.6s + (eval)12.5s: train loss = 0.01226 = (mf)0.00894 + (embed)0.00332, recall = 0.27703, ndcg = 0.21103, precision = 0.03973, map = 0.17882
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_7
# Epoch 7 (train)4.6s + (eval)12.3s: train loss = 0.01138 = (mf)0.00790 + (embed)0.00348, recall = 0.28417, ndcg = 0.21831, precision = 0.04077, map = 0.18585
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_8
# Epoch 8 (train)4.6s + (eval)12.4s: train loss = 0.01020 = (mf)0.00659 + (embed)0.00361, recall = 0.28948, ndcg = 0.22401, precision = 0.04154, map = 0.19142
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_9
# Epoch 9 (train)4.6s + (eval)12.6s: train loss = 0.00989 = (mf)0.00617 + (embed)0.00371, recall = 0.29549, ndcg = 0.23016, precision = 0.04236, map = 0.19740
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_10
# Epoch 10 (train)4.7s + (eval)12.4s: train loss = 0.00895 = (mf)0.00515 + (embed)0.00380, recall = 0.29881, ndcg = 0.23476, precision = 0.04292, map = 0.20233
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_11
# Epoch 11 (train)4.6s + (eval)12.4s: train loss = 0.00863 = (mf)0.00477 + (embed)0.00387, recall = 0.30104, ndcg = 0.23734, precision = 0.04336, map = 0.20475
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_12
# Epoch 12 (train)4.7s + (eval)12.6s: train loss = 0.00801 = (mf)0.00409 + (embed)0.00392, recall = 0.30279, ndcg = 0.23961, precision = 0.04358, map = 0.20713
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_13
# Epoch 13 (train)4.6s + (eval)12.4s: train loss = 0.00814 = (mf)0.00419 + (embed)0.00396, recall = 0.30486, ndcg = 0.24248, precision = 0.04385, map = 0.21010
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_14
# Epoch 14 (train)4.6s + (eval)12.6s: train loss = 0.00810 = (mf)0.00411 + (embed)0.00398, recall = 0.30692, ndcg = 0.24621, precision = 0.04426, map = 0.21424
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_15
# Epoch 15 (train)4.6s + (eval)12.4s: train loss = 0.00784 = (mf)0.00383 + (embed)0.00400, recall = 0.30878, ndcg = 0.24698, precision = 0.04460, map = 0.21468
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_16
# Epoch 16 (train)4.7s + (eval)12.6s: train loss = 0.00739 = (mf)0.00338 + (embed)0.00401, recall = 0.30923, ndcg = 0.24930, precision = 0.04481, map = 0.21730
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_17
# Epoch 17 (train)4.6s + (eval)12.4s: train loss = 0.00718 = (mf)0.00316 + (embed)0.00402, recall = 0.30934, ndcg = 0.24953, precision = 0.04463, map = 0.21769
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_18
# Epoch 18 (train)4.6s + (eval)12.4s: train loss = 0.00740 = (mf)0.00338 + (embed)0.00402, recall = 0.31052, ndcg = 0.25114, precision = 0.04499, map = 0.21916
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_19
# Epoch 19 (train)4.7s + (eval)12.6s: train loss = 0.00666 = (mf)0.00264 + (embed)0.00402, recall = 0.31220, ndcg = 0.25337, precision = 0.04522, map = 0.22162
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_20
# Epoch 20 (train)4.6s + (eval)12.4s: train loss = 0.00701 = (mf)0.00300 + (embed)0.00401, recall = 0.31283, ndcg = 0.25362, precision = 0.04533, map = 0.22168
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_21
# Epoch 21 (train)4.7s + (eval)12.4s: train loss = 0.00672 = (mf)0.00272 + (embed)0.00399, recall = 0.31336, ndcg = 0.25359, precision = 0.04542, map = 0.22148
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_22
# Epoch 22 (train)4.7s + (eval)12.8s: train loss = 0.00658 = (mf)0.00259 + (embed)0.00399, recall = 0.31375, ndcg = 0.25373, precision = 0.04555, map = 0.22156
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_23
# Epoch 23 (train)4.7s + (eval)12.4s: train loss = 0.00681 = (mf)0.00283 + (embed)0.00398, recall = 0.31362, ndcg = 0.25526, precision = 0.04571, map = 0.22345
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_24
# Epoch 24 (train)4.7s + (eval)12.5s: train loss = 0.00658 = (mf)0.00261 + (embed)0.00397, recall = 0.31295, ndcg = 0.25303, precision = 0.04529, map = 0.22086
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_25
# Epoch 25 (train)4.6s + (eval)12.7s: train loss = 0.00630 = (mf)0.00234 + (embed)0.00396, recall = 0.31432, ndcg = 0.25488, precision = 0.04560, map = 0.22279
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_26
# Epoch 26 (train)4.7s + (eval)12.6s: train loss = 0.00650 = (mf)0.00255 + (embed)0.00394, recall = 0.31397, ndcg = 0.25381, precision = 0.04545, map = 0.22156
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_27
# Epoch 27 (train)4.8s + (eval)12.7s: train loss = 0.00626 = (mf)0.00233 + (embed)0.00393, recall = 0.31512, ndcg = 0.25594, precision = 0.04580, map = 0.22375
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_28
# Epoch 28 (train)4.7s + (eval)12.4s: train loss = 0.00599 = (mf)0.00208 + (embed)0.00391, recall = 0.31455, ndcg = 0.25679, precision = 0.04587, map = 0.22490
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_29
# Epoch 29 (train)4.7s + (eval)12.8s: train loss = 0.00627 = (mf)0.00238 + (embed)0.00389, recall = 0.31510, ndcg = 0.25746, precision = 0.04599, map = 0.22553
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_30
# Epoch 30 (train)4.7s + (eval)12.5s: train loss = 0.00596 = (mf)0.00208 + (embed)0.00388, recall = 0.31416, ndcg = 0.25739, precision = 0.04570, map = 0.22590
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_31
# Epoch 31 (train)4.6s + (eval)12.5s: train loss = 0.00599 = (mf)0.00214 + (embed)0.00385, recall = 0.31426, ndcg = 0.25699, precision = 0.04576, map = 0.22544
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_32
# Epoch 32 (train)4.7s + (eval)12.6s: train loss = 0.00594 = (mf)0.00210 + (embed)0.00384, recall = 0.31481, ndcg = 0.25817, precision = 0.04588, map = 0.22684
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_33
# Epoch 33 (train)4.7s + (eval)12.4s: train loss = 0.00583 = (mf)0.00201 + (embed)0.00382, recall = 0.31481, ndcg = 0.25909, precision = 0.04593, map = 0.22788
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_34
# Epoch 34 (train)4.6s + (eval)12.4s: train loss = 0.00596 = (mf)0.00216 + (embed)0.00380, recall = 0.31330, ndcg = 0.25709, precision = 0.04569, map = 0.22575
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_35
# Epoch 35 (train)4.7s + (eval)12.6s: train loss = 0.00589 = (mf)0.00211 + (embed)0.00379, recall = 0.31359, ndcg = 0.25855, precision = 0.04578, map = 0.22741
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_36
# Epoch 36 (train)4.7s + (eval)12.4s: train loss = 0.00589 = (mf)0.00211 + (embed)0.00377, recall = 0.31525, ndcg = 0.26012, precision = 0.04586, map = 0.22915
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_37
# Epoch 37 (train)4.8s + (eval)12.6s: train loss = 0.00558 = (mf)0.00181 + (embed)0.00377, recall = 0.31463, ndcg = 0.25942, precision = 0.04578, map = 0.22837
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_38
# Epoch 38 (train)4.7s + (eval)12.4s: train loss = 0.00559 = (mf)0.00183 + (embed)0.00375, recall = 0.31256, ndcg = 0.25776, precision = 0.04554, map = 0.22689
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_39
# Epoch 39 (train)4.7s + (eval)12.3s: train loss = 0.00578 = (mf)0.00203 + (embed)0.00375, recall = 0.31243, ndcg = 0.25693, precision = 0.04548, map = 0.22566
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_40
# Epoch 40 (train)4.6s + (eval)12.7s: train loss = 0.00571 = (mf)0.00197 + (embed)0.00374, recall = 0.31194, ndcg = 0.25791, precision = 0.04570, map = 0.22697
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_41
# Epoch 41 (train)4.7s + (eval)12.4s: train loss = 0.00561 = (mf)0.00188 + (embed)0.00373, recall = 0.31343, ndcg = 0.25795, precision = 0.04573, map = 0.22673
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_42
# Epoch 42 (train)4.7s + (eval)12.6s: train loss = 0.00570 = (mf)0.00199 + (embed)0.00371, recall = 0.31284, ndcg = 0.25490, precision = 0.04560, map = 0.22306
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_43
# Epoch 43 (train)4.6s + (eval)12.4s: train loss = 0.00549 = (mf)0.00178 + (embed)0.00371, recall = 0.31311, ndcg = 0.25353, precision = 0.04553, map = 0.22138
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_44
# Epoch 44 (train)4.7s + (eval)12.4s: train loss = 0.00558 = (mf)0.00188 + (embed)0.00370, recall = 0.31375, ndcg = 0.25390, precision = 0.04564, map = 0.22149
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_45
# Epoch 45 (train)4.6s + (eval)12.7s: train loss = 0.00547 = (mf)0.00179 + (embed)0.00368, recall = 0.31385, ndcg = 0.25475, precision = 0.04571, map = 0.22251
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_46
# Epoch 46 (train)4.7s + (eval)12.5s: train loss = 0.00553 = (mf)0.00186 + (embed)0.00367, recall = 0.31525, ndcg = 0.25491, precision = 0.04583, map = 0.22240
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_47
# Epoch 47 (train)4.7s + (eval)12.3s: train loss = 0.00544 = (mf)0.00178 + (embed)0.00366, recall = 0.31485, ndcg = 0.25513, precision = 0.04599, map = 0.22266
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_48
# Epoch 48 (train)4.7s + (eval)12.6s: train loss = 0.00517 = (mf)0.00153 + (embed)0.00364, recall = 0.31660, ndcg = 0.25599, precision = 0.04615, map = 0.22336
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_49
# Epoch 49 (train)4.6s + (eval)12.4s: train loss = 0.00521 = (mf)0.00157 + (embed)0.00364, recall = 0.31716, ndcg = 0.25663, precision = 0.04615, map = 0.22386
# Save model to path /kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_50
# Epoch 50 (train)4.6s + (eval)12.6s: train loss = 0.00558 = (mf)0.00195 + (embed)0.00363, recall = 0.31632, ndcg = 0.25691, precision = 0.04610, map = 0.22448
# Took 871.328420069 seconds for training.

# %%
topk_scores = model.recommend_k_items(test, top_k=10, remove_seen=True)

topk_scores.head(20)
# Out:
#     userID  itemID  prediction
# 0    57513    2565   10.072577
# 1    57513   54797    8.433524
# 2    57513  102002    8.211458
# 3    57513   73968    8.194303
# 4    57513  120734    6.756838
# 5    57513   98752    6.482310
# 6    57513   60544    6.357093
# 7    57513   23707    6.214141
# 8    57513   57742    6.206005
# 9    57513   65261    6.041788
# 10   25831  100686   18.022715
# 11   25831   53650   12.479156
# 12   25831  118874   12.248220
# 13   25831   36223   12.152376
# 14   25831  108562   11.908281
# 15   25831   38300   11.831026
# 16   25831    4241   11.592191
# 17   25831   17718   11.189778
# 18   25831  115313   10.973252
# 19   25831   21983   10.687943

# %%
eval_map = map(test, topk_scores, k=10)
eval_ndcg = ndcg_at_k(test, topk_scores, k=10)
eval_precision = precision_at_k(test, topk_scores, k=10)
eval_recall = recall_at_k(test, topk_scores, k=10)

print("MAP:\t%f" % eval_map,
      "NDCG:\t%f" % eval_ndcg,
      "Precision@K:\t%f" % eval_precision,
      "Recall@K:\t%f" % eval_recall, sep='\n')
# Out:
# MAP:	0.224181
# NDCG:	0.256908
# Precision@K:	0.046102
# Recall@K:	0.316321

# %%
user_file = "/kaggle/working/user_embeddings.csv"
item_file = "/kaggle/working/item_embeddings.csv"

# %%
model.infer_embedding(user_file, item_file)

# %%
test_1 = test.loc[test['userID'] == 25831]
test_1.head()
# Out:
#       rating        time  itemID  userID
# 1        5.0  1344211200   55373   25831
# 2221     4.0  1327881600   56106   25831
# 2918     4.0  1348272000    3327   25831
# 6129     4.0  1332892800  110917   25831
# 8376     5.0  1350518400   53650   25831

# %%
topk_scores = model.recommend_k_items(test_1, top_k=10, remove_seen=True)

topk_scores.head(20)
# Out:
#    userID  itemID  prediction
# 0   25831  100686   18.022717
# 1   25831   53650   12.479157
# 2   25831  118874   12.248222
# 3   25831   36223   12.152377
# 4   25831  108562   11.908280
# 5   25831   38300   11.831025
# 6   25831    4241   11.592193
# 7   25831   17718   11.189777
# 8   25831  115313   10.973251
# 9   25831   21983   10.687944

# %%
import shutil

# Specify the directory you want to zip
directory_path = '/kaggle/working/tests/resources/deeprec/lightgcn/model/lightgcn_model/epoch_26'

# Specify the output zip file path (without the .zip extension)
zip_file_path = 'epoch26'

# Create the zip file
shutil.make_archive(zip_file_path, 'zip', directory_path)
# Out:
# '/kaggle/working/epoch26.zip'

# %%
books = pd.read_csv('/kaggle/input/books-fil/books_filtered.csv')
books.head(2)
# Out:
#                                 Title  \
# 0                Hunting The Hard Way
# 1  Night World: Daughters Of Darkness
#
#                                          description          authors  \
# 0  Thrilling stories about hunting wildcat, buffa...  ['Howard Hill']
# 1  "There’s something strange about the new girls...   ['L.J. Smith']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=0lbZC...
# 1  http://books.google.com/books/content?id=c9icD...
#
#                                          previewLink           publisher  \
# 0  http://books.google.nl/books?id=0lbZCRYJXYIC&p...     Derrydale Press
# 1  http://books.google.nl/books?id=c9icDQAAQBAJ&p...  Simon and Schuster
#
#   publishedDate               categories  id  \
# 0    2000-04-26  ['Sports & Recreation']  18
# 1    2016-12-06     ['Juvenile Fiction']  55
#
#                               combined_text_features  \
# 0  thrilling story about hunt wildcat buffalo mou...
# 1  there s something strange about the new girl i...
#
#                                            embedding
# 0  [-0.0234614   0.26560947 -0.1578814  -0.157919...
# 1  [ 0.08108633  0.2756923  -0.21181437 -0.068135...

# %%
def get_liked_books_ratings(liked_books, top_n=1):
    # Combine train and test data
    combined_df = pd.concat([train, test], ignore_index=True)

    # Filter combined data by the liked books
    liked_books_ratings = combined_df[combined_df['itemID'].isin(liked_books)]

    # Find users who like multiple books from the liked_books list
    user_liked_books_count = liked_books_ratings.groupby('userID')['itemID'].count().reset_index()
    user_liked_books_count.columns = ['userID', 'liked_books_count']

    # Filter users who liked at least 2 books from the liked_books list
    common_users = user_liked_books_count[user_liked_books_count['liked_books_count'] > 1]['userID']
    
    if not common_users.empty:
        # Filter ratings by common users
        common_users_ratings = liked_books_ratings[liked_books_ratings['userID'].isin(common_users)]
    else:
        # If no common users, get top users for each liked book
        top_users_ratings = pd.DataFrame()
        
        for book_id in liked_books:
            book_ratings = liked_books_ratings[liked_books_ratings['itemID'] == book_id]
            top_users = book_ratings.nlargest(top_n, 'rating')  # Get top users based on rating
            top_users_ratings = pd.concat([top_users_ratings, top_users], ignore_index=True)
        
        common_users_ratings = top_users_ratings

    return common_users_ratings

# %%
import pandas as pd

def get_predictions_for_user(id=0, k=10 ,is_new=False, liked_books_ids=[]):
    
    if is_new:
        df = get_liked_books_ratings(liked_books_ids)
    else:
    # Filter the test DataFrame to get the data for the specified user
        df = test.loc[test['userID'] == id]
    
    # Get the top k recommendations for the user, removing items they've already seen
    topk_scores = model.recommend_k_items(df, k, remove_seen=True)
    
    # Ensure topk_scores is ranked by the 'prediction' column
    topk_scores = topk_scores.sort_values(by='prediction', ascending=False)
    
    rec_ids = topk_scores['itemID']
    
#     # Append title IDs of the recommended books
#     for book_id in topk_scores['itemID']:
#         rec_ids.append(test.loc[test['itemID'] == book_id]['itemID'].values[0])
    
    # Retrieve the book titles, authors, and categories from the books DataFrame using the title_id
    recommended_books = books.loc[books['id'].isin(rec_ids), ['Title', 'authors', 'categories']]
    
    return recommended_books

# %%
liked_books_ids = [18, 55]  
df = get_liked_books_ratings(liked_books_ids)
df.head()
# Out:
#    rating        time  itemID  userID
# 0     5.0  1355011200      18   16846
# 1     5.0  1022976000      55   34971

# %%
df = get_predictions_for_user(is_new=True,liked_books_ids = [18, 55] )
df.head(10)
# Out:
#                                                   Title  \
# 39                                 Small-Circle Jujitsu
# 87                            The Clan of the Cave Bear
# 537          Deep Wizardry: Young Wizard Series, Book 2
# 751                                  The Princess Bride
# 1143       Stealing the Network: How to Own a Continent
# 2197           Clan of the Cave Bear (Earth's Children)
# 2300           Inside Photoshop 7 (Inside (New Riders))
# 2495  Chinese Fast Wrestling for Fighting: The Art o...
# 4427                           Darkfever (Fever Series)
# 4695            Harry Potter and the Chamber of Secrets
#
#                                          authors  \
# 39                                 ['Wally Jay']
# 87                              ['Jean M. Auel']
# 537                              ['Diane Duane']
# 751                 ['Cary Elwes', 'Joe Layden']
# 1143  ['Ryan Russell', 'Joe Grand', 'Tom Craig']
# 2197                            ['Jean M. Auel']
# 2300                       ['Gary David Bouton']
# 2495             ['Shou-Yu Liang', 'Tai D. Ngo']
# 4427                      ['Karen Marie Moning']
# 4695                           ['J. K. Rowling']
#
#                          categories
# 39          ['Sports & Recreation']
# 87             ['American fiction']
# 537            ['Juvenile Fiction']
# 751   ['Biography & Autobiography']
# 1143                  ['Computers']
# 2197                    ['Fiction']
# 2300                  ['Computers']
# 2495                        ['Art']
# 4427                    ['Fiction']
# 4695           ['Juvenile Fiction']

# %%
df = get_predictions_for_user(0)
df.head(10)
# Out:
#                                                    Title  \
# 1989                            Jane Eyre (New Windmill)
# 2046                    Pride & Prejudice (New Windmill)
# 2232                                 Pride and Prejudice
# 3179   Jane Eyre: Complete and Unabridged (Puffin Cla...
# 3468                 Pride & Prejudice (Classic Library)
# 4967                         Jane Eyre (Signet classics)
# 5402               Frankenstein (Running Press classics)
# 9139                Pride & Prejudice (Penguin Classics)
# 9766                             Jane Eyre (Large Print)
# 11967                       Jane Eyre (Penguin Classics)
#
#                                    authors  \
# 1989                  ['Charlotte Brontë']
# 2046                         ['Ibi Zoboi']
# 2232                       ['Jane Austen']
# 3179                   ['Charlote Brontë']
# 3468                         ['Ibi Zoboi']
# 4967                  ['Charlotte Brontë']
# 5402       ['Mary Wollstonecraft Shelley']
# 9139                         ['Ibi Zoboi']
# 9766   ['Charlotte Brontë', 'Marc Cactus']
# 11967                 ['Charlotte Bronte']
#
#                                     categories
# 1989                       ['Charity-schools']
# 2046                   ['Young Adult Fiction']
# 2232                               ['Fiction']
# 3179                               ['Fiction']
# 3468                   ['Young Adult Fiction']
# 4967                               ['Fiction']
# 5402   ['Frankenstein (Fictitious character)']
# 9139                   ['Young Adult Fiction']
# 9766                               ['Fiction']
# 11967                              ['Fiction']

# %%
print('hello')
# Out:
# hello

# %%
combined_df = pd.concat([train, test], ignore_index=True)
combined_df.head()
# Out:
#    rating        time  itemID  userID
# 0     5.0  1355702400   92408   41587
# 1     5.0  1356220800   32520   24303
# 2     4.0  1330560000  112766   56189
# 3     4.0  1006128000   97297    3294
# 4     5.0  1290816000   20794   50340

# %% [markdown]
# # With full data

# %%
data = ImplicitCF(
    train=combined_df,test=test, seed=0,
    col_user='userID',
    col_item='itemID',
    col_rating='rating'
)

# %%
model = LightGCN(hparams, data, seed=0)
# Out:
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.

# %%
with Timer() as train_time:
    model.fit()

print("Took {} seconds for training.".format(train_time.interval))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 2
#       1 with Timer() as train_time:
# ----> 2     model.fit()
#       4 print("Took {} seconds for training.".format(train_time.interval))
#
# File /kaggle/working/./recommenders_microsoft/recommenders/models/deeprec/models/graphrec/lightgcn.py:219, in LightGCN.fit(self)
#     217 for idx in range(n_batch):
#     218     users, pos_items, neg_items = self.data.train_loader(self.batch_size)
# --> 219     _, batch_loss, batch_mf_loss, batch_emb_loss = self.sess.run(
#     220         [self.opt, self.loss, self.mf_loss, self.emb_loss],
#     221         feed_dict={
#     222             self.users: users,
#     223             self.pos_items: pos_items,
#     224             self.neg_items: neg_items,
#     225         },
#     226     )
#     227     loss += batch_loss / n_batch
#     228     mf_loss += batch_mf_loss / n_batch
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/client/session.py:972, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     969 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     971 try:
# --> 972   result = self._run(None, fetches, feed_dict, options_ptr,
#     973                      run_metadata_ptr)
#     974   if run_metadata:
#     975     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/client/session.py:1215, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1212 # We only want to really perform the run if fetches or targets are provided,
#    1213 # or if the call is a partial run that specifies feeds.
#    1214 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1215   results = self._do_run(handle, final_targets, final_fetches,
#    1216                          feed_dict_tensor, options, run_metadata)
#    1217 else:
#    1218   results = []
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/client/session.py:1395, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1392   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1394 if handle is None:
# -> 1395   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1396                        run_metadata)
#    1397 else:
#    1398   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/client/session.py:1402, in BaseSession._do_call(self, fn, *args)
#    1400 def _do_call(self, fn, *args):
#    1401   try:
# -> 1402     return fn(*args)
#    1403   except errors.OpError as e:
#    1404     message = compat.as_text(e.message)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/client/session.py:1385, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1382 def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1383   # Ensure any changes to the graph are reflected in the runtime.
#    1384   self._extend_graph()
# -> 1385   return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1386                                   target_list, run_metadata)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/client/session.py:1478, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1476 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1477                         run_metadata):
# -> 1478   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1479                                           fetch_list, target_list,
#    1480                                           run_metadata)
#
# KeyboardInterrupt:

# %%
item_embeddings = pd.read_csv('/kaggle/working/item_embeddings.csv', header=None)
item_embeddings.head()
# Out:
#                                                    0
# 0  92408\t-0.072949335 0.045973893 -0.22545972 0....
# 1  32520\t0.36792058 -0.4730116 -0.24796146 0.065...
# 2  112766\t0.93160146 1.5612078 -0.63366807 -0.22...
# 3  97297\t-0.54975337 -0.78646016 -0.7324774 -0.3...
# 4  20794\t-0.026288548 0.83312374 -0.32008472 0.2...

# %%
import pandas as pd

# Define the path to the input file
input_file = '/kaggle/working/item_embeddings.csv'

# Initialize lists to store the ids and embeddings
ids = []
embeddings = []

# Read the file line by line
with open(input_file, 'r') as file:
    for line in file:
        # Split the line into id and embedding parts
        parts = line.strip().split('\t')
        id = parts[0]
        embedding_str = parts[1]
        
#         print('id :' + id,'emb: '+ embedding_str)
        # Convert the embedding string to a list of floats
        embedding = embedding_str.split(' ')
        
        # Append the id and embedding to the lists
        ids.append(id)
        embeddings.append(embedding)

# Create a DataFrame from the lists
df = pd.DataFrame({'id': ids, 'str_embedding': embeddings})

# Save the structured DataFrame to a new CSV file
df.to_csv('structured_item_embeddings.csv', index=False)

# Display the DataFrame
print(df.head())
# Out:
#        id                                      str_embedding
# 0   92408  [-0.072949335, 0.045973893, -0.22545972, 0.852...
# 1   32520  [0.36792058, -0.4730116, -0.24796146, 0.065620...
# 2  112766  [0.93160146, 1.5612078, -0.63366807, -0.227508...
# 3   97297  [-0.54975337, -0.78646016, -0.7324774, -0.3064...
# 4   20794  [-0.026288548, 0.83312374, -0.32008472, 0.2779...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12584 entries, 0 to 12583
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             12584 non-null  object
#  1   str_embedding  12584 non-null  object
# dtypes: object(2)
# memory usage: 196.8+ KB

# %%
type(float(df['str_embedding'].loc[0][0]))
# Out:
# float

# %%
# Convert 'id' column to integers
df['id'] = pd.to_numeric(df['id'], errors='coerce').astype('Int64')

# %%
embeddings = []
for str_embedding in df['str_embedding']:
    embeddings.append(np.asarray(str_embedding, dtype=float))

# %%
df['embedding'] = embeddings

# %%
df.head()
# Out:
#        id                                      str_embedding  \
# 0   92408  [-0.072949335, 0.045973893, -0.22545972, 0.852...
# 1   32520  [0.36792058, -0.4730116, -0.24796146, 0.065620...
# 2  112766  [0.93160146, 1.5612078, -0.63366807, -0.227508...
# 3   97297  [-0.54975337, -0.78646016, -0.7324774, -0.3064...
# 4   20794  [-0.026288548, 0.83312374, -0.32008472, 0.2779...
#
#                                            embedding
# 0  [-0.072949335, 0.045973893, -0.22545972, 0.852...
# 1  [0.36792058, -0.4730116, -0.24796146, 0.065620...
# 2  [0.93160146, 1.5612078, -0.63366807, -0.227508...
# 3  [-0.54975337, -0.78646016, -0.7324774, -0.3064...
# 4  [-0.026288548, 0.83312374, -0.32008472, 0.2779...

# %%
type(float(df['embedding'].loc[0][0]))
# Out:
# float

# %%
df.drop(columns=['str_embedding'], inplace=True)

# %%
df.head()
# Out:
#        id                                          embedding
# 0   92408  [-0.072949335, 0.045973893, -0.22545972, 0.852...
# 1   32520  [0.36792058, -0.4730116, -0.24796146, 0.065620...
# 2  112766  [0.93160146, 1.5612078, -0.63366807, -0.227508...
# 3   97297  [-0.54975337, -0.78646016, -0.7324774, -0.3064...
# 4   20794  [-0.026288548, 0.83312374, -0.32008472, 0.2779...

# %%
# Save the updated DataFrame to a new CSV file if needed
df.to_csv('updated_item_embeddings.csv', index=False)

# %%
len(df['embedding'].loc[0])
# Out:
# 64
